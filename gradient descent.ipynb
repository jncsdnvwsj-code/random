# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: x**3  + 3*x**2 - 2*x - 5
grad_f = lambda x: 3*x**2 + 6*x - 2
norm_grad_f = lambda x: np.sqrt((grad_f(x))**2)

def gradient_descent(x_0, t):
    x = x_0
    N = 0
    while norm_grad_f(x) > eps:
        x = x - t * grad_f
        grad_f = 1/norm_grad_f * grad_f
        N = N + 1
        print(f"Iteration {N}: x = {x:.4f}, f(x) = {f(x):.4f}")
    return x

x_0 = 0
t = 0.1
N = 100
eps = 10**(-3)

minimum = gradient_descent(x_0, t)
print(f"\nLocal minimum occurs at x = {minimum:.4f}, f(x) = {f(minimum):.4f}")

x_vals = np.linspace(-10, 2, 100)
y_vals = f(x_vals)
plt.plot(x_vals, y_vals, label="f(x) = x^2 + 4x + 4")
plt.scatter(minimum, f(minimum), color='red', label="Local Minimum")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gradient Descent Visualization")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 23
#      20 N = 100
#      21 eps = 10**(-3)
# ---> 23 minimum = gradient_descent(x_0, t)
#      24 print(f"\nLocal minimum occurs at x = {minimum:.4f}, f(x) = {f(minimum):.4f}")
#      26 x_vals = np.linspace(-10, 2, 100)
#
# Cell In[2], line 12, in gradient_descent(x_0, t)
#      10 N = 0
#      11 while norm_grad_f(x) > eps:
# ---> 12     x = x - t * grad_f
#      13     grad_f = 1/norm_grad_f * grad_f
#      14     N = N + 1
#
# UnboundLocalError: cannot access local variable 'grad_f' where it is not associated with a value
