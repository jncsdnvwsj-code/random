# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2 + 4*x + 4

def grad_f(x):
    return 2*x + 4

def norm_grad_f(x):
    return np.sqrt((grad_f(x))**2)

def gradient_descent(x_0, t):
    x = x_0
    N = 0
    while norm_grad_f(x) > eps:
        x = x - t * grad_f(x)  # update step
        grad_f = 1/norm_grad_f(x) * grad_f(x)
        N = N + 1
        print(f"Iteration {N}: x = {x:.4f}, f(x) = {f(x):.4f}")
    return x

x_0 = 0
t = 0.1
N = 100
eps = 10**(-3)

minimum = gradient_descent(x_0, t)
print(f"\nLocal minimum occurs at x = {minimum:.4f}, f(x) = {f(minimum):.4f}")

x_vals = np.linspace(-10, 2, 100)
y_vals = f(x_vals)
plt.plot(x_vals, y_vals, label="f(x) = x^2 + 4x + 4")
plt.scatter(minimum, f(minimum), color='red', label="Local Minimum")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gradient Descent Visualization")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[4], line 28
#      25 N = 100
#      26 eps = 10**(-3)
# ---> 28 minimum = gradient_descent(x_0, t)
#      29 print(f"\nLocal minimum occurs at x = {minimum:.4f}, f(x) = {f(minimum):.4f}")
#      31 x_vals = np.linspace(-10, 2, 100)
#
# Cell In[4], line 17, in gradient_descent(x_0, t)
#      15 N = 0
#      16 while norm_grad_f(x) > eps:
# ---> 17     x = x - t * grad_f(x)  # update step
#      18     grad_f = 1/norm_grad_f(x) * grad_f(x)
#      19     N = N + 1
#
# UnboundLocalError: cannot access local variable 'grad_f' where it is not associated with a value
