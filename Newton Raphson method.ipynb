# %%
import numpy as np

f = lambda x: x**3  + 3*x**2 - 2*x - 5
df = lambda x: 3*x**2 + 6*x - 2

def newton_raphson(f, df, x_0, eps):
    if abs(f(x_0)) < eps:
        return x0
    else:
        return newton_raphson(f, df, x_0 - f(x_0)/df(x_0), eps)
    
estimate = newton_raphson(f, df, 0, 1e-6)
print("estimate =", estimate)
# Out:
# estimate = 0.29
