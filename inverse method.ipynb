# %%
from numpy.linalg import inv
import numpy as np

def normalize(x):
    fac = abs(x).max()
    x_n = x / x.max()
    return fac, x_n

a = np.array([[0, 2], 
              [2, 3]])

a_inv = inv(a)

for i in range(8):
    x = np.dot(a_inv, x)
    lambda_1, x = normalize(x)
    
print('Eigenvalue:', lambda_1)
print('Eigenvector:', x)
# Out:
# Eigenvalue: 2.0
# Eigenvector: [ 1.  -0.5]
